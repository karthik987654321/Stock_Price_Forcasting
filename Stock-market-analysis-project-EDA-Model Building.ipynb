# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import datetime

# %%
bajaj=pd.read_csv('bajaj_stock.csv')
bajaj
# Out:
#            Date      Symbol Series  Prev Close    Open     High      Low  \
# 0    2021-01-01  BAJFINANCE     EQ     5295.20  5310.2  5338.00  5250.00
# 1    2021-01-04  BAJFINANCE     EQ     5280.15  5324.0  5324.00  5196.20
# 2    2021-01-05  BAJFINANCE     EQ     5216.20  5218.0  5224.20  5062.50
# 3    2021-01-06  BAJFINANCE     EQ     5119.00  5130.0  5168.35  4990.30
# 4    2021-01-07  BAJFINANCE     EQ     5030.30  5065.0  5131.55  5021.30
# ..          ...         ...    ...         ...     ...      ...      ...
# 243  2021-12-27  BAJFINANCE     EQ     6852.00  6751.0  6908.80  6654.05
# 244  2021-12-28  BAJFINANCE     EQ     6890.75  6980.0  6980.00  6861.75
# 245  2021-12-29  BAJFINANCE     EQ     6906.65  6884.9  6949.95  6853.05
# 246  2021-12-30  BAJFINANCE     EQ     6911.65  6899.9  6944.95  6856.90
# 247  2021-12-31  BAJFINANCE     EQ     6871.10  6882.0  6999.00  6875.55
#
#         Last    Close     VWAP   Volume      Turnover  Trades  \
# ...

# %%
bajaj.set_index(pd.to_datetime(bajaj['Date']),inplace=True)
bajaj=bajaj.drop(columns=['Date','Volume','Turnover','Trades','Symbol','Series','Deliverable Volume','%Deliverble'],errors='ignore')
bajaj
# Out:
#             Prev Close    Open     High      Low     Last    Close     VWAP
# Date
# 2021-01-01     5295.20  5310.2  5338.00  5250.00  5272.00  5280.15  5302.83
# 2021-01-04     5280.15  5324.0  5324.00  5196.20  5217.10  5216.20  5245.98
# 2021-01-05     5216.20  5218.0  5224.20  5062.50  5133.00  5119.00  5120.58
# 2021-01-06     5119.00  5130.0  5168.35  4990.30  5020.95  5030.30  5058.00
# 2021-01-07     5030.30  5065.0  5131.55  5021.30  5077.55  5081.00  5079.71
# ...                ...     ...      ...      ...      ...      ...      ...
# 2021-12-27     6852.00  6751.0  6908.80  6654.05  6895.05  6890.75  6799.10
# 2021-12-28     6890.75  6980.0  6980.00  6861.75  6904.00  6906.65  6924.52
# 2021-12-29     6906.65  6884.9  6949.95  6853.05  6906.00  6911.65  6916.26
# 2021-12-30     6911.65  6899.9  6944.95  6856.90  6869.25  6871.10  6893.66
# 2021-12-31     6871.10  6882.0  6999.00  6875.55  6968.05  6977.30  6953.92
#
# [248 rows x 7 columns]

# %%
infy=pd.read_csv('infy_stock.csv')
infy
# Out:
#            Date Symbol Series  Prev Close    Open     High      Low     Last  \
# 0    2021-01-01   INFY     EQ     1255.80  1257.9  1265.50  1255.80  1259.50
# 1    2021-01-04   INFY     EQ     1260.45  1269.0  1290.00  1261.15  1288.00
# 2    2021-01-05   INFY     EQ     1288.25  1282.0  1299.00  1275.05  1290.35
# 3    2021-01-06   INFY     EQ     1293.80  1300.0  1302.00  1268.05  1282.50
# 4    2021-01-07   INFY     EQ     1282.10  1296.0  1297.65  1255.50  1266.50
# ..          ...    ...    ...         ...     ...      ...      ...      ...
# 243  2021-12-27   INFY     EQ     1863.50  1860.0  1874.50  1845.05  1869.40
# 244  2021-12-28   INFY     EQ     1866.15  1880.7  1895.90  1878.40  1885.20
# 245  2021-12-29   INFY     EQ     1888.00  1883.5  1893.80  1876.40  1883.25
# 246  2021-12-30   INFY     EQ     1885.55  1884.5  1909.80  1874.35  1897.00
# 247  2021-12-31   INFY     EQ     1892.85  1890.0  1898.35  1871.65  1893.00
#
# ...

# %%
infy.set_index(pd.to_datetime(infy['Date']),inplace=True)
infy=infy.drop(columns=['Date','Volume','Turnover','Trades','Symbol','Series','Deliverable Volume','%Deliverble'],errors='ignore')
infy
# Out:
#             Prev Close    Open     High      Low     Last    Close     VWAP
# Date
# 2021-01-01     1255.80  1257.9  1265.50  1255.80  1259.50  1260.45  1261.66
# 2021-01-04     1260.45  1269.0  1290.00  1261.15  1288.00  1288.25  1278.28
# 2021-01-05     1288.25  1282.0  1299.00  1275.05  1290.35  1293.80  1289.82
# 2021-01-06     1293.80  1300.0  1302.00  1268.05  1282.50  1282.10  1288.38
# 2021-01-07     1282.10  1296.0  1297.65  1255.50  1266.50  1262.15  1266.59
# ...                ...     ...      ...      ...      ...      ...      ...
# 2021-12-27     1863.50  1860.0  1874.50  1845.05  1869.40  1866.15  1863.95
# 2021-12-28     1866.15  1880.7  1895.90  1878.40  1885.20  1888.00  1887.13
# 2021-12-29     1888.00  1883.5  1893.80  1876.40  1883.25  1885.55  1885.99
# 2021-12-30     1885.55  1884.5  1909.80  1874.35  1897.00  1892.85  1895.39
# 2021-12-31     1892.85  1890.0  1898.35  1871.65  1893.00  1887.75  1887.20
#
# [248 rows x 7 columns]

# %%
maruti=pd.read_csv('maruti_stock.csv')
maruti
# Out:
#            Date  Symbol Series  Prev Close     Open     High      Low  \
# 0    2021-01-01  MARUTI     EQ     7649.60  7654.00  7748.50  7650.00
# 1    2021-01-04  MARUTI     EQ     7691.30  7739.00  7755.20  7642.60
# 2    2021-01-05  MARUTI     EQ     7702.30  7660.00  7673.00  7586.00
# 3    2021-01-06  MARUTI     EQ     7655.45  7654.00  7749.00  7555.50
# 4    2021-01-07  MARUTI     EQ     7628.60  7676.00  7704.40  7552.10
# ..          ...     ...    ...         ...      ...      ...      ...
# 243  2021-12-27  MARUTI     EQ     7317.10  7277.10  7330.00  7186.20
# 244  2021-12-28  MARUTI     EQ     7289.50  7320.00  7359.00  7255.10
# 245  2021-12-29  MARUTI     EQ     7297.45  7297.70  7365.00  7240.45
# 246  2021-12-30  MARUTI     EQ     7350.05  7350.00  7395.15  7255.40
# 247  2021-12-31  MARUTI     EQ     7282.25  7290.05  7449.50  7290.05
#
#         Last    Close     VWAP  Volume      Turnover  Trades  \
# 0    7687.00  7691.30  7704.92  767574  5.914094e+14   55693
# ...

# %%
maruti.set_index(pd.to_datetime(maruti['Date']),inplace=True)
maruti=maruti.drop(columns=['Date','Volume','Turnover','Trades','Symbol','Series','Deliverable Volume','%Deliverble'],errors='ignore')
maruti
# Out:
#             Prev Close     Open     High      Low     Last    Close     VWAP
# Date
# 2021-01-01     7649.60  7654.00  7748.50  7650.00  7687.00  7691.30  7704.92
# 2021-01-04     7691.30  7739.00  7755.20  7642.60  7691.05  7702.30  7697.13
# 2021-01-05     7702.30  7660.00  7673.00  7586.00  7657.20  7655.45  7635.41
# 2021-01-06     7655.45  7654.00  7749.00  7555.50  7625.25  7628.60  7670.88
# 2021-01-07     7628.60  7676.00  7704.40  7552.10  7576.85  7566.05  7620.30
# ...                ...      ...      ...      ...      ...      ...      ...
# 2021-12-27     7317.10  7277.10  7330.00  7186.20  7280.00  7289.50  7279.08
# 2021-12-28     7289.50  7320.00  7359.00  7255.10  7305.00  7297.45  7307.20
# 2021-12-29     7297.45  7297.70  7365.00  7240.45  7350.00  7350.05  7318.86
# 2021-12-30     7350.05  7350.00  7395.15  7255.40  7273.00  7282.25  7314.25
# 2021-12-31     7282.25  7290.05  7449.50  7290.05  7420.00  7426.45  7412.34
#
# [248 rows x 7 columns]

# %% [markdown]
# # Statistical Representation of Data

# %%
bajaj.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count   248.000000   248.000000   248.000000   248.000000   248.000000
# mean   6224.591129  6235.961089  6322.498185  6147.055444  6229.270968
# std     977.829745   983.353529   985.183571   972.809027   977.855820
# min    4479.600000  4450.000000  4504.000000  4362.000000  4478.800000
# 25%    5436.812500  5430.000000  5523.425000  5343.362500  5444.362500
# 50%    6101.525000  6088.950000  6174.100000  6022.600000  6115.050000
# 75%    7135.725000  7152.500000  7215.950000  7040.000000  7129.412500
# max    7929.300000  8050.000000  8050.000000  7861.300000  7935.000000
#
#              Close         VWAP
# count   248.000000   248.000000
# mean   6231.373790  6235.109234
# std     977.190663   978.096849
# min    4479.600000  4435.760000
# 25%    5443.437500  5434.522500
# 50%    6116.900000  6117.565000
# 75%    7135.725000  7133.237500
# max    7929.300000  7935.120000

# %%
infy.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count   248.000000   248.000000   248.000000   248.000000   248.000000
# mean   1532.947379  1535.601210  1550.275605  1520.786492  1535.862500
# std     187.397691   187.234775   188.531488   186.535592   187.443525
# min    1239.050000  1250.550000  1265.500000  1231.000000  1250.000000
# 25%    1350.450000  1348.175000  1364.300000  1336.137500  1348.900000
# 50%    1559.800000  1558.425000  1572.100000  1542.800000  1560.700000
# 75%    1706.500000  1705.862500  1725.225000  1691.337500  1707.612500
# max    1892.850000  1890.000000  1909.800000  1878.400000  1897.000000
#
#              Close         VWAP
# count   248.000000   248.000000
# mean   1535.495565  1535.604718
# std     187.909702   187.707078
# min    1239.050000  1253.290000
# 25%    1351.287500  1352.222500
# 50%    1560.575000  1559.980000
# 75%    1706.875000  1707.185000
# max    1892.850000  1895.390000

# %%
maruti.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count   248.000000   248.000000   248.000000   248.000000   248.000000
# mean   7232.178629  7242.228226  7322.808266  7153.635887  7228.511290
# std     390.252751   391.406376   407.278496   376.544771   387.533375
# min    6455.650000  6430.000000  6530.000000  6400.000000  6438.350000
# 25%    6906.725000  6925.750000  6983.637500  6850.325000  6905.750000
# 50%    7219.250000  7238.125000  7314.000000  7151.100000  7221.000000
# 75%    7498.937500  7522.000000  7602.000000  7442.000000  7499.462500
# max    8274.750000  8234.000000  8368.000000  8140.000000  8240.000000
#
#              Close         VWAP
# count   248.000000   248.000000
# mean   7231.278831  7238.062177
# std     389.543025   393.178396
# min    6455.650000  6477.280000
# 25%    6906.725000  6906.892500
# 50%    7219.250000  7218.675000
# 75%    7497.062500  7512.167500
# max    8274.750000  8225.920000

# %% [markdown]
# # Checking missing values in datasets

# %%
bajaj.isna().any()
# Out:
# Prev Close    False
# Open          False
# High          False
# Low           False
# Last          False
# Close         False
# VWAP          False
# dtype: bool

# %%
infy.isna().any()
# Out:
# Prev Close    False
# Open          False
# High          False
# Low           False
# Last          False
# Close         False
# VWAP          False
# dtype: bool

# %%
maruti.isna().any()
# Out:
# Prev Close    False
# Open          False
# High          False
# Low           False
# Last          False
# Close         False
# VWAP          False
# dtype: bool

# %% [markdown]
# # Checking datatypes

# %%
bajaj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 248 entries, 2021-01-01 to 2021-12-31
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Prev Close  248 non-null    float64
#  1   Open        248 non-null    float64
#  2   High        248 non-null    float64
#  3   Low         248 non-null    float64
#  4   Last        248 non-null    float64
#  5   Close       248 non-null    float64
#  6   VWAP        248 non-null    float64
# dtypes: float64(7)
# memory usage: 15.5 KB

# %%
infy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 248 entries, 2021-01-01 to 2021-12-31
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Prev Close  248 non-null    float64
#  1   Open        248 non-null    float64
#  2   High        248 non-null    float64
#  3   Low         248 non-null    float64
#  4   Last        248 non-null    float64
#  5   Close       248 non-null    float64
#  6   VWAP        248 non-null    float64
# dtypes: float64(7)
# memory usage: 15.5 KB

# %%
maruti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 248 entries, 2021-01-01 to 2021-12-31
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Prev Close  248 non-null    float64
#  1   Open        248 non-null    float64
#  2   High        248 non-null    float64
#  3   Low         248 non-null    float64
#  4   Last        248 non-null    float64
#  5   Close       248 non-null    float64
#  6   VWAP        248 non-null    float64
# dtypes: float64(7)
# memory usage: 15.5 KB

# %%
bajaj['Close'].plot(legend=True, figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
infy['Close'].plot(legend=True, figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
maruti['Close'].plot(legend=True, figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
bajaj['Volume'].plot(legend=True, figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
infy['Volume'].plot(legend=True, figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
maruti['Volume'].plot(legend=True, figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
bajaj['Daily Return']=bajaj['Close'].pct_change()
bajaj
# Out:
#             Prev Close    Open     High      Low     Last    Close     VWAP  \
# Date
# 2021-01-01     5295.20  5310.2  5338.00  5250.00  5272.00  5280.15  5302.83
# 2021-01-04     5280.15  5324.0  5324.00  5196.20  5217.10  5216.20  5245.98
# 2021-01-05     5216.20  5218.0  5224.20  5062.50  5133.00  5119.00  5120.58
# 2021-01-06     5119.00  5130.0  5168.35  4990.30  5020.95  5030.30  5058.00
# 2021-01-07     5030.30  5065.0  5131.55  5021.30  5077.55  5081.00  5079.71
# ...                ...     ...      ...      ...      ...      ...      ...
# 2021-12-27     6852.00  6751.0  6908.80  6654.05  6895.05  6890.75  6799.10
# 2021-12-28     6890.75  6980.0  6980.00  6861.75  6904.00  6906.65  6924.52
# 2021-12-29     6906.65  6884.9  6949.95  6853.05  6906.00  6911.65  6916.26
# 2021-12-30     6911.65  6899.9  6944.95  6856.90  6869.25  6871.10  6893.66
# 2021-12-31     6871.10  6882.0  6999.00  6875.55  6968.05  6977.30  6953.92
#
#             Daily Return
# Date
# ...

# %%
infy['Daily Return']=infy['Close'].pct_change()
infy
# Out:
#             Prev Close    Open     High      Low     Last    Close     VWAP  \
# Date
# 2021-01-01     1255.80  1257.9  1265.50  1255.80  1259.50  1260.45  1261.66
# 2021-01-04     1260.45  1269.0  1290.00  1261.15  1288.00  1288.25  1278.28
# 2021-01-05     1288.25  1282.0  1299.00  1275.05  1290.35  1293.80  1289.82
# 2021-01-06     1293.80  1300.0  1302.00  1268.05  1282.50  1282.10  1288.38
# 2021-01-07     1282.10  1296.0  1297.65  1255.50  1266.50  1262.15  1266.59
# ...                ...     ...      ...      ...      ...      ...      ...
# 2021-12-27     1863.50  1860.0  1874.50  1845.05  1869.40  1866.15  1863.95
# 2021-12-28     1866.15  1880.7  1895.90  1878.40  1885.20  1888.00  1887.13
# 2021-12-29     1888.00  1883.5  1893.80  1876.40  1883.25  1885.55  1885.99
# 2021-12-30     1885.55  1884.5  1909.80  1874.35  1897.00  1892.85  1895.39
# 2021-12-31     1892.85  1890.0  1898.35  1871.65  1893.00  1887.75  1887.20
#
#             Daily Return
# Date
# ...

# %%
maruti['Daily Return']=maruti['Close'].pct_change()
maruti
# Out:
#             Prev Close     Open     High      Low     Last    Close     VWAP  \
# Date
# 2021-01-01     7649.60  7654.00  7748.50  7650.00  7687.00  7691.30  7704.92
# 2021-01-04     7691.30  7739.00  7755.20  7642.60  7691.05  7702.30  7697.13
# 2021-01-05     7702.30  7660.00  7673.00  7586.00  7657.20  7655.45  7635.41
# 2021-01-06     7655.45  7654.00  7749.00  7555.50  7625.25  7628.60  7670.88
# 2021-01-07     7628.60  7676.00  7704.40  7552.10  7576.85  7566.05  7620.30
# ...                ...      ...      ...      ...      ...      ...      ...
# 2021-12-27     7317.10  7277.10  7330.00  7186.20  7280.00  7289.50  7279.08
# 2021-12-28     7289.50  7320.00  7359.00  7255.10  7305.00  7297.45  7307.20
# 2021-12-29     7297.45  7297.70  7365.00  7240.45  7350.00  7350.05  7318.86
# 2021-12-30     7350.05  7350.00  7395.15  7255.40  7273.00  7282.25  7314.25
# 2021-12-31     7282.25  7290.05  7449.50  7290.05  7420.00  7426.45  7412.34
#
#             Daily Return
# Date
# ...

# %% [markdown]
# # Daywise daily returns of stocks

# %%
sns.distplot(bajaj['Daily Return'],bins=100)
# Out:
# C:\Users\homep\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Daily Return', ylabel='Density'>

# %%
sns.distplot(infy['Daily Return'],bins=100)
# Out:
# C:\Users\homep\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Daily Return', ylabel='Density'>

# %%
sns.distplot(maruti['Daily Return'],bins=100)
# Out:
# C:\Users\homep\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Daily Return', ylabel='Density'>

# %% [markdown]
# # Compairing open and close price of stocks

# %%
bajaj['Open'].plot(figsize=(16,6))
bajaj['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
infy['Open'].plot(figsize=(16,6))
infy['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
maruti['Open'].plot(figsize=(16,6))
maruti['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # EDA

# %%
#Displaying all BOX-PLOTS 
import matplotlib.pyplot as plt
import seaborn as sns
infy = infy.drop(['Daily Return'], axis=1)
infy.plot(kind='box',figsize=(20,10));

# %%
#correlation od dataset
infy.corr()
# Out:
#             Prev Close      Open      High       Low      Last     Close  \
# Prev Close    1.000000  0.998076  0.996557  0.996179  0.994314  0.994340
# Open          0.998076  1.000000  0.998158  0.997584  0.995758  0.995605
# High          0.996557  0.998158  1.000000  0.997786  0.998155  0.998071
# Low           0.996179  0.997584  0.997786  1.000000  0.998400  0.998433
# Last          0.994314  0.995758  0.998155  0.998400  1.000000  0.999893
# Close         0.994340  0.995605  0.998071  0.998433  0.999893  1.000000
# VWAP          0.996320  0.997656  0.999246  0.999294  0.999204  0.999249
#
#                 VWAP
# Prev Close  0.996320
# Open        0.997656
# High        0.999246
# Low         0.999294
# Last        0.999204
# Close       0.999249
# VWAP        1.000000

# %%
bajaj = bajaj.drop(['Daily Return'], axis=1)
bajaj.plot(kind='box',figsize=(20,10));

# %%
bajaj.corr()
# Out:
#             Prev Close      Open      High       Low      Last     Close  \
# Prev Close    1.000000  0.998831  0.995668  0.995704  0.991884  0.991990
# Open          0.998831  1.000000  0.996458  0.996813  0.992699  0.992782
# High          0.995668  0.996458  1.000000  0.996494  0.997686  0.997794
# Low           0.995704  0.996813  0.996494  1.000000  0.996858  0.996945
# Last          0.991884  0.992699  0.997686  0.996858  1.000000  0.999938
# Close         0.991990  0.992782  0.997794  0.996945  0.999938  1.000000
# VWAP          0.994996  0.995959  0.998858  0.998773  0.998843  0.998949
#
#                 VWAP
# Prev Close  0.994996
# Open        0.995959
# High        0.998858
# Low         0.998773
# Last        0.998843
# Close       0.998949
# VWAP        1.000000

# %%
maruti = maruti.drop(['Daily Return'], axis=1)
maruti.plot(kind='box',figsize=(20,10));

# %%
maruti.corr()
# Out:
#             Prev Close      Open      High       Low      Last     Close  \
# Prev Close    1.000000  0.993825  0.973301  0.976136  0.950389  0.950477
# Open          0.993825  1.000000  0.976749  0.980939  0.954211  0.953967
# High          0.973301  0.976749  1.000000  0.978594  0.986122  0.986148
# Low           0.976136  0.980939  0.978594  1.000000  0.980874  0.981002
# Last          0.950389  0.954211  0.986122  0.980874  1.000000  0.999574
# Close         0.950477  0.953967  0.986148  0.981002  0.999574  1.000000
# VWAP          0.968920  0.972679  0.994138  0.990507  0.994050  0.994308
#
#                 VWAP
# Prev Close  0.968920
# Open        0.972679
# High        0.994138
# Low         0.990507
# Last        0.994050
# Close       0.994308
# VWAP        1.000000

# %%
# scatter plots for all variables
sns.pairplot(infy)

# %%
sns.pairplot(maruti)

# %%
sns.pairplot(bajaj)

# %%
# cumulative moving average
# smoothing factor - 0.1
infy['EMA_0.1'] = infy.Close.ewm(alpha=0.1, adjust=False).mean()

# smoothing factor - 0.3
infy['EMA_0.3'] = infy.Close.ewm(alpha=0.3, adjust=False).mean()
infy.head()
# Out:
#             Prev Close    Open     High      Low     Last    Close     VWAP  \
# Date
# 2021-01-01     1255.80  1257.9  1265.50  1255.80  1259.50  1260.45  1261.66
# 2021-01-04     1260.45  1269.0  1290.00  1261.15  1288.00  1288.25  1278.28
# 2021-01-05     1288.25  1282.0  1299.00  1275.05  1290.35  1293.80  1289.82
# 2021-01-06     1293.80  1300.0  1302.00  1268.05  1282.50  1282.10  1288.38
# 2021-01-07     1282.10  1296.0  1297.65  1255.50  1266.50  1262.15  1266.59
#
#                EMA_0.1     EMA_0.3
# Date
# 2021-01-01  1260.45000  1260.45000
# 2021-01-04  1263.23000  1268.79000
# 2021-01-05  1266.28700  1276.29300
# 2021-01-06  1267.86830  1278.03510
# 2021-01-07  1267.29647  1273.26957

# %%
# colors for the line plot
colors = ['green', 'red', 'orange']

# line plot - the average Closing value
infy[['Close', 'EMA_0.1', 'EMA_0.3']].plot(color=colors, linewidth=3, figsize=(12,6), alpha=0.8)

# modify ticks size
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(labels=['Close', 'EMA - alpha=0.1', 'EMA - alpha=0.3'], fontsize=14)

# title and labels
plt.title('The Exponential Moving Average of Closing value', fontsize=20)
plt.xlabel('Date', fontsize=16)
plt.ylabel('Closeing value', fontsize=16)
# Out:
# Text(0, 0.5, 'Closeing value')

# %%
# cumulative moving average
# smoothing factor - 0.1
maruti['EMA_0.1'] = maruti.Close.ewm(alpha=0.1, adjust=False).mean()

# smoothing factor - 0.3
maruti['EMA_0.3'] = maruti.Close.ewm(alpha=0.3, adjust=False).mean()
maruti.head()
# Out:
#             Prev Close    Open    High     Low     Last    Close     VWAP  \
# Date
# 2021-01-01     7649.60  7654.0  7748.5  7650.0  7687.00  7691.30  7704.92
# 2021-01-04     7691.30  7739.0  7755.2  7642.6  7691.05  7702.30  7697.13
# 2021-01-05     7702.30  7660.0  7673.0  7586.0  7657.20  7655.45  7635.41
# 2021-01-06     7655.45  7654.0  7749.0  7555.5  7625.25  7628.60  7670.88
# 2021-01-07     7628.60  7676.0  7704.4  7552.1  7576.85  7566.05  7620.30
#
#                EMA_0.1     EMA_0.3
# Date
# 2021-01-01  7691.30000  7691.30000
# 2021-01-04  7692.40000  7694.60000
# 2021-01-05  7688.70500  7682.85500
# 2021-01-06  7682.69450  7666.57850
# 2021-01-07  7671.03005  7636.41995

# %%
# colors for the line plot
colors = ['green', 'red', 'orange']

# line plot - the average Closing value
maruti[['Close', 'EMA_0.1', 'EMA_0.3']].plot(color=colors, linewidth=3, figsize=(12,6), alpha=0.8)

# modify ticks size
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(labels=['Close', 'EMA - alpha=0.1', 'EMA - alpha=0.3'], fontsize=14)

# title and labels
plt.title('The Exponential Moving Average of Closing value', fontsize=20)
plt.xlabel('Date', fontsize=16)
plt.ylabel('Closeing value', fontsize=16)
# Out:
# Text(0, 0.5, 'Closeing value')

# %%
# cumulative moving average
# smoothing factor - 0.1
bajaj['EMA_0.1'] = bajaj.Close.ewm(alpha=0.1, adjust=False).mean()

# smoothing factor - 0.3
bajaj['EMA_0.3'] = bajaj.Close.ewm(alpha=0.3, adjust=False).mean()
bajaj.head()
# Out:
#             Prev Close    Open     High     Low     Last    Close     VWAP  \
# Date
# 2021-01-01     5295.20  5310.2  5338.00  5250.0  5272.00  5280.15  5302.83
# 2021-01-04     5280.15  5324.0  5324.00  5196.2  5217.10  5216.20  5245.98
# 2021-01-05     5216.20  5218.0  5224.20  5062.5  5133.00  5119.00  5120.58
# 2021-01-06     5119.00  5130.0  5168.35  4990.3  5020.95  5030.30  5058.00
# 2021-01-07     5030.30  5065.0  5131.55  5021.3  5077.55  5081.00  5079.71
#
#                 EMA_0.1      EMA_0.3
# Date
# 2021-01-01  5280.150000  5280.150000
# 2021-01-04  5273.755000  5260.965000
# 2021-01-05  5258.279500  5218.375500
# 2021-01-06  5235.481550  5161.952850
# 2021-01-07  5220.033395  5137.666995

# %%
# colors for the line plot
colors = ['green', 'red', 'orange']

# line plot - the average Closing value
bajaj[['Close', 'EMA_0.1', 'EMA_0.3']].plot(color=colors, linewidth=3, figsize=(12,6), alpha=0.8)

# modify ticks size
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(labels=['Close', 'EMA - alpha=0.1', 'EMA - alpha=0.3'], fontsize=14)

# title and labels
plt.title('The Exponential Moving Average of Closing value', fontsize=20)
plt.xlabel('Date', fontsize=16)
plt.ylabel('Closeing value', fontsize=16)
# Out:
# Text(0, 0.5, 'Closeing value')

# %% [markdown]
# # Feature Scaling Bajaj data

# %%
training_set=bajaj['Close']
training_set=pd.DataFrame(training_set)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
training_set_scaled=scaler.fit_transform(training_set)

# %%
X_train=[]
Y_train=[]
for i in range(15,248):
    X_train.append(training_set_scaled[i-15:i,0])
    Y_train.append(training_set_scaled[i,0])
X_train,Y_train=np.array(X_train),np.array(Y_train)

# %%
# Reshaping
X_train=np.reshape(X_train,(X_train.shape[0],X_train.shape[1],1))

# %% [markdown]
# # Model Building for Bajaj Stock

# %% [markdown]
# # RNN LSTM model

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
regressor=Sequential()

# %%
# Adding a first LSTM layer and some dropout regularization
regressor.add(LSTM(units=50, return_sequences=True, input_shape= (X_train.shape[1],1)))
regressor.add(Dropout(0.2))

# Adding a second LSTM layer and some dropout regularization
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))

# Adding a third LSTM layer and some dropout regularization
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))

# Adding a fourth LSTM layer and some dropout regularization
regressor.add(LSTM(units=50))
regressor.add(Dropout(0.2))

# Adding the output layer
regressor.add(Dense(units=1))

# %%
# Compiling the RNN 
regressor.compile(optimizer= 'adam', loss= 'mean_squared_error', metrics=['accuracy'])

# Fitting the RNN to the training set
regressor.fit(X_train, Y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 9s 31ms/step - loss: 0.2593 - accuracy: 0.0043
# Epoch 2/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0551 - accuracy: 0.0086
# Epoch 3/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0344 - accuracy: 0.0086
# Epoch 4/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.0200 - accuracy: 0.0086
# Epoch 5/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0187 - accuracy: 0.0086
# Epoch 6/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.0151 - accuracy: 0.0086
# Epoch 7/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0140 - accuracy: 0.0086
# Epoch 8/100
# 8/8 [==============================] - 0s 25ms/step - loss: 0.0133 - accuracy: 0.0086
# Epoch 9/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0141 - accuracy: 0.0086
# Epoch 10/100
# ...

# %%
testing_set=bajaj['Close']
testing_set=pd.DataFrame(testing_set)

# %%
testing_set_scaled=scaler.fit_transform(testing_set)

# %%
X_test=[]
Y_test=[]
for i in range(15,248):
    X_test.append(testing_set_scaled[i-15:i,0])
    Y_test.append(testing_set_scaled[i,0])
X_test,Y_test=np.array(X_test),np.array(Y_test)

# %%
# Reshaping
X_test=np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))

# %%
# Fitting the RNN to the testing set
regressor.fit(X_test, Y_test, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 0s 36ms/step - loss: 0.0088 - accuracy: 0.0086
# Epoch 2/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.0072 - accuracy: 0.0086
# Epoch 3/100
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0065 - accuracy: 0.0086
# Epoch 4/100
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0072 - accuracy: 0.0086
# Epoch 5/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.0072 - accuracy: 0.0086
# Epoch 6/100
# 8/8 [==============================] - 0s 39ms/step - loss: 0.0079 - accuracy: 0.0086
# Epoch 7/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.0075 - accuracy: 0.0086
# Epoch 8/100
# 8/8 [==============================] - 0s 36ms/step - loss: 0.0068 - accuracy: 0.0086
# Epoch 9/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.0074 - accuracy: 0.0086
# Epoch 10/100
# ...

# %% [markdown]
# # Linear model

# %%
X=bajaj[['Open','High','Low']]
Y=bajaj['Close']

# %% [markdown]
# # Spliting Bajaj dataset

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,random_state=0)

# %%
X_train.shape
# Out:
# (186, 3)

# %%
X_test.shape
# Out:
# (62, 3)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import confusion_matrix, accuracy_score
regressor = LinearRegression()

# %%
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
regressor.coef_
# Out:
# array([-0.5664433 ,  0.91561039,  0.65000699])

# %%
regressor.intercept_
# Out:
# -20.7832005291084

# %%
predicted=regressor.predict(X_test)

# %%
X_test
# Out:
#                Open     High      Low
# Date
# 2021-12-31  6882.00  6999.00  6875.55
# 2021-09-07  7528.90  7566.25  7407.20
# 2021-04-27  4747.00  4889.85  4746.55
# 2021-08-11  6176.10  6199.95  6057.00
# 2021-08-04  6343.00  6477.45  6315.00
# ...             ...      ...      ...
# 2021-09-24  7949.85  7949.85  7725.65
# 2021-08-05  6354.00  6355.50  6232.00
# 2021-08-26  6900.00  6993.25  6855.00
# 2021-11-15  7579.00  7627.45  7490.00
# 2021-07-07  6220.00  6286.00  6160.40
#
# [62 rows x 3 columns]

# %%
df=pd.DataFrame(Y_test,predicted)

# %%
Y_test
# Out:
# Date
# 2021-12-31    6977.30
# 2021-09-07    7457.30
# 2021-04-27    4865.05
# 2021-08-11    6167.80
# 2021-08-04    6359.15
#                ...
# 2021-09-24    7793.40
# 2021-08-05    6248.25
# 2021-08-26    6931.95
# 2021-11-15    7534.25
# 2021-07-07    6198.60
# Name: Close, Length: 62, dtype: float64

# %%
dfr=pd.DataFrame({'Actual_Price':Y_test,'Predicted_Price':predicted})
dfr
# Out:
#             Actual_Price  Predicted_Price
# Date
# 2021-12-31       6977.30      6958.466659
# 2021-09-07       7457.30      7456.990696
# 2021-04-27       4865.05      4852.798578
# 2021-08-11       6167.80      6094.637284
# 2021-08-04       6359.15      6421.881583
# ...                  ...              ...
# 2021-09-24       7793.40      7776.769258
# 2021-08-05       6248.25      6250.041440
# 2021-08-26       6931.95      6929.648276
# 2021-11-15       7534.25      7538.467821
# 2021-07-07       6198.60      6215.769420
#
# [62 rows x 2 columns]

# %%
regressor.score(X_test,Y_test)
# Out:
# 0.9979591379214272

# %% [markdown]
# # Graph of actual and predicted close price of Bajaj stock

# %%
graph=dfr.head(20)
graph.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
graph=dfr
graph.plot(kind= 'bar', figsize=(20,15))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
training_set=infy['Close']
training_set=pd.DataFrame(training_set)

# %% [markdown]
# # Feature Scaling for Infosis data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
training_set_scaled=scaler.fit_transform(training_set)

# %%
X_train=[]
Y_train=[]
for i in range(15,248):
    X_train.append(training_set_scaled[i-15:i,0])
    Y_train.append(training_set_scaled[i,0])
X_train,Y_train=np.array(X_train),np.array(Y_train)

# %%
# Reshaping
X_train=np.reshape(X_train,(X_train.shape[0],X_train.shape[1],1))

# %% [markdown]
# # Model Building for Infosis stock

# %% [markdown]
# # RNN LSTM model

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
regressor=Sequential()

# %%
# Adding a first LSTM layer and some dropout regularization
regressor.add(LSTM(units=50, return_sequences=True, input_shape= (X_train.shape[1],1)))
regressor.add(Dropout(0.2))

# Adding a second LSTM layer and some dropout regularization
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))

# Adding a third LSTM layer and some dropout regularization
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))

# Adding a fourth LSTM layer and some dropout regularization
regressor.add(LSTM(units=50))
regressor.add(Dropout(0.2))

# Adding the output layer
regressor.add(Dense(units=1))

# %%
# Compiling the RNN 
regressor.compile(optimizer= 'adam', loss= 'mean_squared_error', metrics=['accuracy'])

# Fitting the RNN to the training set
regressor.fit(X_train, Y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 11s 46ms/step - loss: 0.1419 - accuracy: 0.0043
# Epoch 2/100
# 8/8 [==============================] - 0s 47ms/step - loss: 0.0272 - accuracy: 0.0086
# Epoch 3/100
# 8/8 [==============================] - 0s 48ms/step - loss: 0.0192 - accuracy: 0.0086
# Epoch 4/100
# 8/8 [==============================] - 0s 47ms/step - loss: 0.0165 - accuracy: 0.0086
# Epoch 5/100
# 8/8 [==============================] - 0s 45ms/step - loss: 0.0121 - accuracy: 0.0086
# Epoch 6/100
# 8/8 [==============================] - 0s 48ms/step - loss: 0.0106 - accuracy: 0.0086
# Epoch 7/100
# 8/8 [==============================] - 0s 47ms/step - loss: 0.0089 - accuracy: 0.0086
# Epoch 8/100
# 8/8 [==============================] - 0s 45ms/step - loss: 0.0100 - accuracy: 0.0086
# Epoch 9/100
# 8/8 [==============================] - 0s 48ms/step - loss: 0.0086 - accuracy: 0.0086
# Epoch 10/100
# ...

# %%
testing_set=infy['Close']
testing_set=pd.DataFrame(testing_set)

# %%
testing_set_scaled=scaler.fit_transform(testing_set)

# %%
X_test=[]
Y_test=[]
for i in range(15,248):
    X_test.append(testing_set_scaled[i-15:i,0])
    Y_test.append(testing_set_scaled[i,0])
X_test,Y_test=np.array(X_test),np.array(Y_test)

# %%
# Reshaping
X_test=np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))

# %%
# Fitting the RNN to the testing set
regressor.fit(X_test, Y_test, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.0054 - accuracy: 0.0086
# Epoch 2/100
# 8/8 [==============================] - 0s 45ms/step - loss: 0.0067 - accuracy: 0.0086
# Epoch 3/100
# 8/8 [==============================] - 0s 49ms/step - loss: 0.0062 - accuracy: 0.0086
# Epoch 4/100
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0062 - accuracy: 0.0086
# Epoch 5/100
# 8/8 [==============================] - 0s 47ms/step - loss: 0.0063 - accuracy: 0.0086
# Epoch 6/100
# 8/8 [==============================] - 0s 57ms/step - loss: 0.0056 - accuracy: 0.0086
# Epoch 7/100
# 8/8 [==============================] - 0s 46ms/step - loss: 0.0067 - accuracy: 0.0086
# Epoch 8/100
# 8/8 [==============================] - 0s 46ms/step - loss: 0.0065 - accuracy: 0.0086
# Epoch 9/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.0067 - accuracy: 0.0086
# Epoch 10/100
# ...

# %% [markdown]
# # Linear model

# %%
X=infy[['Open','High','Low','Volume']]
Y=infy['Close']

# %% [markdown]
# # Spliting Infosis dataset

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,random_state=0)

# %%
X_train.shape
# Out:
# (186, 4)

# %%
X_test.shape
# Out:
# (62, 4)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import confusion_matrix, accuracy_score
regressor = LinearRegression()

# %%
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
regressor.coef_
# Out:
# array([-5.08133070e-01,  6.85203571e-01,  8.26404875e-01,  1.94484264e-07])

# %%
regressor.intercept_
# Out:
# -4.379137032400649

# %%
predicted=regressor.predict(X_test)

# %%
X_test
# Out:
#                Open     High      Low   Volume
# Date
# 2021-12-31  1890.00  1898.35  1871.65  4619420
# 2021-09-07  1730.00  1734.90  1704.00  3520341
# 2021-04-27  1346.00  1353.00  1340.15  3636115
# 2021-08-11  1674.80  1684.00  1668.00  4899639
# 2021-08-04  1669.10  1679.90  1639.05  6740391
# ...             ...      ...      ...      ...
# 2021-09-24  1758.00  1788.00  1752.45  8280446
# 2021-08-05  1649.50  1666.00  1647.05  5420536
# 2021-08-26  1734.00  1746.00  1720.00  5302248
# 2021-11-15  1782.10  1800.00  1775.50  4354074
# 2021-07-07  1566.05  1570.55  1544.65  4797120
#
# [62 rows x 4 columns]

# %%
df=pd.DataFrame(Y_test,predicted)

# %%
dfr=pd.DataFrame({'Actual Price':Y_test,'Predicted Price':predicted})
dfr
# Out:
#             Actual Price  Predicted Price
# Date
# 2021-12-31       1887.75      1883.644648
# 2021-09-07       1706.65      1714.188884
# 2021-04-27       1348.50      1346.967842
# 2021-08-11       1677.55      1677.878644
# 2021-08-04       1649.25      1654.399244
# ...                  ...              ...
# 2021-09-24       1763.85      1777.310550
# 2021-08-05       1653.55      1661.188871
# 2021-08-26       1727.70      1733.331143
# 2021-11-15       1787.15      1791.572000
# 2021-07-07       1564.60      1553.444791
#
# [62 rows x 2 columns]

# %%
regressor.score(X_test,Y_test)
# Out:
# 0.9986204402577219

# %% [markdown]
# # Graph of actual and predicted close price of Infosis stock

# %%
graph=dfr.head(20)
graph.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
training_set=maruti['Close']
training_set=pd.DataFrame(training_set)

# %% [markdown]
# # Feature Scaling for Maruti data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
training_set_scaled=scaler.fit_transform(training_set)

# %%
X_train=[]
Y_train=[]
for i in range(15,248):
    X_train.append(training_set_scaled[i-15:i,0])
    Y_train.append(training_set_scaled[i,0])
X_train,Y_train=np.array(X_train),np.array(Y_train)

# %%
# Reshaping
X_train=np.reshape(X_train,(X_train.shape[0],X_train.shape[1],1))

# %% [markdown]
# # Model Building for Maruti stock

# %% [markdown]
# # RNN LSTM model

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
regressor=Sequential()

# %%
# Adding a first LSTM layer and some dropout regularization
regressor.add(LSTM(units=50, return_sequences=True, input_shape= (X_train.shape[1],1)))
regressor.add(Dropout(0.2))

# Adding a second LSTM layer and some dropout regularization
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))

# Adding a third LSTM layer and some dropout regularization
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))

# Adding a fourth LSTM layer and some dropout regularization
regressor.add(LSTM(units=50))
regressor.add(Dropout(0.2))

# Adding the output layer
regressor.add(Dense(units=1))

# %%
# Compiling the RNN 
regressor.compile(optimizer= 'adam', loss= 'mean_squared_error', metrics=['accuracy'])

# Fitting the RNN to the training set
regressor.fit(X_train, Y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 11s 54ms/step - loss: 0.1098 - accuracy: 0.0043
# Epoch 2/100
# 8/8 [==============================] - 0s 49ms/step - loss: 0.0315 - accuracy: 0.0086
# Epoch 3/100
# 8/8 [==============================] - 0s 48ms/step - loss: 0.0308 - accuracy: 0.0043
# Epoch 4/100
# 8/8 [==============================] - 0s 48ms/step - loss: 0.0281 - accuracy: 0.0086
# Epoch 5/100
# 8/8 [==============================] - 0s 47ms/step - loss: 0.0254 - accuracy: 0.0043
# Epoch 6/100
# 8/8 [==============================] - 0s 52ms/step - loss: 0.0250 - accuracy: 0.0086ETA: 0s - loss: 0.0242 - accuracy:
# Epoch 7/100
# 8/8 [==============================] - 0s 48ms/step - loss: 0.0220 - accuracy: 0.0043
# Epoch 8/100
# 8/8 [==============================] - 0s 47ms/step - loss: 0.0237 - accuracy: 0.0043
# Epoch 9/100
# 8/8 [==============================] - 0s 55ms/step - loss: 0.0217 - accuracy: 0.0043
# Epoch 10/100
# ...

# %%
testing_set=maruti['Close']
testing_set=pd.DataFrame(testing_set)

# %%
testing_set_scaled=scaler.fit_transform(testing_set)

# %%
X_test=[]
Y_test=[]
for i in range(15,248):
    X_test.append(testing_set_scaled[i-15:i,0])
    Y_test.append(testing_set_scaled[i,0])
X_test,Y_test=np.array(X_test),np.array(Y_test)

# %%
# Reshaping
X_test=np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))

# %%
# Fitting the RNN to the testing set
regressor.fit(X_test, Y_test, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 0s 49ms/step - loss: 0.0083 - accuracy: 0.0086
# Epoch 2/100
# 8/8 [==============================] - 0s 48ms/step - loss: 0.0089 - accuracy: 0.0086
# Epoch 3/100
# 8/8 [==============================] - 0s 49ms/step - loss: 0.0086 - accuracy: 0.0086
# Epoch 4/100
# 8/8 [==============================] - 0s 57ms/step - loss: 0.0081 - accuracy: 0.0086
# Epoch 5/100
# 8/8 [==============================] - 0s 51ms/step - loss: 0.0076 - accuracy: 0.0086
# Epoch 6/100
# 8/8 [==============================] - 0s 50ms/step - loss: 0.0076 - accuracy: 0.0086
# Epoch 7/100
# 8/8 [==============================] - 0s 50ms/step - loss: 0.0073 - accuracy: 0.0086
# Epoch 8/100
# 8/8 [==============================] - 0s 55ms/step - loss: 0.0080 - accuracy: 0.0086
# Epoch 9/100
# 8/8 [==============================] - 0s 55ms/step - loss: 0.0084 - accuracy: 0.0086
# Epoch 10/100
# ...

# %% [markdown]
# # Linear model

# %%
X=maruti[['Open','High','Low','Volume']]
Y=maruti['Close']

# %% [markdown]
# # Spliting Maruti dataset

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,random_state=0)

# %%
X_train.shape
# Out:
# (186, 4)

# %%
X_test.shape
# Out:
# (62, 4)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import confusion_matrix, accuracy_score
regressor = LinearRegression()

# %%
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
regressor.coef_
# Out:
# array([-6.21424778e-01,  8.98736372e-01,  7.02777963e-01, -9.57081293e-06])

# %%
regressor.intercept_
# Out:
# 133.95446069566242

# %%
predicted=regressor.predict(X_test)

# %%
X_test
# Out:
#                Open     High      Low   Volume
# Date
# 2021-12-31  7290.05  7449.50  7290.05   313398
# 2021-09-07  6879.90  6929.90  6853.70   743783
# 2021-04-27  6669.95  6709.00  6542.00  1610651
# 2021-08-11  7002.00  7095.00  6925.15   414311
# 2021-08-04  7220.00  7248.60  7003.50   484122
# ...             ...      ...      ...      ...
# 2021-09-24  6850.00  7037.80  6848.00  1649962
# 2021-08-05  7072.00  7079.95  7006.00   495133
# 2021-08-26  6700.00  6701.35  6591.00  1199429
# 2021-11-15  7452.00  7579.85  7452.00   314414
# 2021-07-07  7528.00  7581.00  7433.65   395336
#
# [62 rows x 4 columns]

# %%
df=pd.DataFrame(Y_test,predicted)

# %%
dfr=pd.DataFrame({'Actual Price':Y_test,'Predicted Price':predicted})
dfr
# Out:
#             Actual Price  Predicted Price
# Date
# 2021-12-31       7426.45      7419.160373
# 2021-09-07       6877.15      6896.278029
# 2021-04-27       6568.75      6600.862774
# 2021-08-11       7021.50      7022.150238
# 2021-08-04       7102.90      7079.120049
# ...                  ...              ...
# 2021-09-24       6952.25      6999.153580
# 2021-08-05       7027.55      7021.170588
# 2021-08-26       6608.60      6613.685475
# 2021-11-15       7503.10      7549.476083
# 2021-07-07       7449.40      7489.610882
#
# [62 rows x 2 columns]

# %%
regressor.score(X_test,Y_test)
# Out:
# 0.9897614378834756

# %% [markdown]
# # Graph of actual and predicted close price of Infosis stock

# %%
graph=dfr.head(20)
graph.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>
